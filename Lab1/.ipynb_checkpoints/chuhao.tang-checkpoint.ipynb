# %%
ciphertext_filename = f'chuhao.tang.txt'
ciphertext_file = open(ciphertext_filename, 'r')
ciphertext = ciphertext_file.read()
print(ciphertext)
# Out:
# HZEGOUXKEQOTFKCMXGQUKMHKGFWWUTJUXQSMXMOLEGQSMLGELH
# KGYUQTEKCHZEGEDUGQSFAUFGYSHTCALWEQSMXGMLMGSECYTUGM
# CFDUKQSMTHISQUWQSHGZUXTCGHBAUKQSGZSMKAHKMUDMKMCUKH
# QQSMXMHGGUAMQSHKIGQXEKIMQUAMMPMKKUZHKQSMXMWTMYQHUK
# QSEQSMKMPMXGEZAMEKCGUAMQSHKIGQXEKIMXLMQHKQSMGSECUZ
# LXMAMAOXEKYMQSEQHSEPMUWALWHXGQYSHTCHGSEGGUYHEQHUKG
# ZHQSSHGZSHQMIXEPMGQUKMHKQSMYSFXYSLEXCEKCUWQSMHKCMW
# HKEOTMYUADEGGHUKHFGMCQUWMMTWUXHQTLHKIUFQETUKMQSMXM
# HKQSMCEXJKHISQZSMKUFXTHQQTMDEXTUFXZEGZEXAEKCOXHISQ
# ZHQSWHXMEKCYEKCTMEKCQSMCUUXGUWUFXSUFGMZMXMETAUGQYX
# FMTTLHQGMMAMCQUAMGUAMQHAMGOUTQMCEKCTUYJMCEIEHKGQHQ

# %%
language = 'en'
import substitution  # Today's toolbox
solver = substitution.Solver(ciphertext_filename, language)

# %%
solver.symbol_frequencies()
# Out:
#      Symbol in "en"  Expected Ciphertext Symbol  Occurrences
# Rank
# 1                 e        68                 M           67
# 2                 t        50                 Q           51
# 3                 a        44                 U           43
# 4                 o        41                 H           42
# 5                 i        39                 K           42
# 6                 n        38                 G           40
# 7                 s        35                 E           38
# 8                 r        33                 S           38
# 9                 h        30                 X           31
# 10                l        22                 C           24
# 11                d        21                 T           22
# 12                c        16                 A           18
# 13                u        14                 Z           14
# 14                m        13                 F           13
# 15                f        12                 W           13
# 16                p        11                 Y           13
# 17                g        10                 L           11
# 18                w        10                 I           10
# 19                y         9                 O            7
# 20                b         8                 D            5
# 21                v         5                 P            4
# 22                k         3                 J            3
# 23                x         1                 B            1
# 24                j         0                 N            0
# 25                q         0                 R            0
# 26                z         0                 V            0

# %%
solver.language_histogram()
solver.ciphertext_histogram()

# %%
solver.language_bigrams()
solver.ciphertext_bigrams()
# Out:
#    e   t  a  o  i  n  s  r   h  l  d  c  u  m  f  p  g  w  y  b  v  k x j  q z
# e  2   5        2  3  4  8  13  3  2  3     2  1  2  1  1     3  2  1
# t  4   2  6  2  4  6  6  3   1  1  2  2  2     2           1
# a  3   3           2  4  3   4  1  2  2     3  1  1     1
# o  2   6     1  3  3  3  2   2  1  2  3     1  2  1  1     1
# i  2   7           2  2  4   3  3  3        1  1        2        1
# n  6      9  7  9     1                  1
# s  7   1  3  2  5  2  2  2         1     2
# r  8   1  5  6  1                        2           1
# h     17              1               2                 2
# l  2      4     2               3        1        1           1
# d  5               6            1
# c  3      2     3  1  1
# u      1     5        1                                       1            1
# m  2         2  1
# f  1         5  1
# p  1      1  1        1                           1
# g  1               4
# w  2         1        1
# y      1  1                     2                             1
# b         1
# v         1
# k
# x
# j
# q                                                 2
# z
#    M   Q  U   H   K  G   E   S  X  C  T  A  Z  F  W  Y  L  I  O  D  P  J  B N  \
# M  3   2          6  5      15  7  2  4  9  1  1  1  1  2  2     1  4  1
# Q  7   2  1   8   7  9   5   3  1  3  1        1  2  1
# U  2   6  1   3   2  5       1     4  4  3  1     3  2     1  2  2     1
# H  5   6          3  2   1   7  2  2  2  1  3     3  1  3
# K  5      9  13   1     11      1              1                       1
# G  5   1  3   4   4  3   6   1  5  2           3        1  2
# E  4   1      1   2  3       6  4  4  1  1  4     1  1  2  1     2
# S     22      1      3       1  1           3        4     3
# X  9   2  5   2          4                     4     1  1  1  2
# C  8             10      2      1     3
# T  3   3  2   2          2      3  2  1           1  1        2
# A  3      6   1   1             1  1  1     1  1  1                       1
# Z  1   2  2   2      5   1      1
# F         6   1      1       2  1  1  1
# W  2      5                  1        1        1  1     2
# Y  3   2  2       1  2          1  2
# L  2                     1   1  1     2  2  1                 1
# I  1          3   5      1
# O  1   1             2   1         1     1
# D  1      1              1               1     1
# P  2                     2
# J                               1     1              1
# B             1
# N
# R
# V
#
#   R V
# M
# Q
# U
# H
# K
# G
# E
# S
# X
# C
# T
# A
# Z
# F
# W
# Y
# L
# I
# O
# D
# P
# J
# B
# N
# R
# V
